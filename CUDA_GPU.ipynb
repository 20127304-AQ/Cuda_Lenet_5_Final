# %%
# !git clone https://github.com/20127304-AQ/Cuda_Lenet_5_Final
# Out:
# Cloning into 'Cuda_Lenet_5_Final'...
# remote: Enumerating objects: 507, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 507 (delta 21), reused 19 (delta 8), pack-reused 467
# Receiving objects: 100% (507/507), 47.36 MiB | 20.67 MiB/s, done.
# Resolving deltas: 100% (85/85), done.
# Updating files: 100% (414/414), done.

# %%
# %cd /content/Cuda_Lenet_5_Final
# Out:
# /content/Cuda_Lenet_5_Final

# %%
# !nvcc --compile setup.cc -I ../libgputk/ -I./

# !nvcc --compile src/network.cc -o src/network.o -I ../libgputk/ -I./

# !nvcc --compile src/mnist.cc -o src/mnist.o -I ../libgputk/ -I./

# !nvcc --compile src/layer/ave_pooling.cc -o src/layer/ave_pooling.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv.cc -o src/layer/conv.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv_cpu.cc -o src/layer/conv_cpu.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv_cust.cc -o src/layer/conv_cust.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/fully_connected.cc -o src/layer/fully_connected.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/max_pooling.cc -o src/layer/max_pooling.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/relu.cc -o src/layer/relu.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/sigmoid.cc -o src/layer/sigmoid.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/softmax.cc -o src/layer/softmax.o -I ../libgputk/ -I./

# !nvcc --compile src/layer/custom/cpu-new-forward.cc -o src/layer/custom/cpu-new-forward.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/custom/gpu-utils.cu -o src/layer/custom/gpu-utils.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/custom/gpu-new-forward-basic.cu -o src/layer/custom/gpu-new-forward-basic.o -I ../libgputk/ -I./

# !nvcc --compile src/loss/cross_entropy_loss.cc -o src/loss/cross_entropy_loss.o -I ../libgputk/ -I./
# !nvcc --compile src/loss/mse_loss.cc -o src/loss/mse_loss.o -I ../libgputk/ -I./

# !nvcc --compile demo.cc -I ../libgputk/ -I./
# !nvcc -o demo -lm -lcuda -lrt demo.o setup.o src/network.o src/mnist.o src/layer/*.o src/loss/*.o src/layer/custom/*.o -I ../libgputk/ -I./

# %%
! /content/Cuda_Lenet_5_Final/demo 128
# Out:
# Test batch size: 128
# Loading fashion-mnist data...60000,28,28
# 10000,28,28
# Done
# Loading model...Done
# Conv-GPU==
# Basic
# Layer Time: 183.313 ms
# Op Time: 55.4884 ms
# Conv-GPU==
# Basic
# Layer Time: 67.7359 ms
# Op Time: 20.9477 ms
#
# Test Accuracy: 0.9787

# %%
# !nvcc --compile setup.cc -I ../libgputk/ -I./

# !nvcc --compile src/network.cc -o src/network.o -I ../libgputk/ -I./

# !nvcc --compile src/mnist.cc -o src/mnist.o -I ../libgputk/ -I./

# !nvcc --compile src/layer/ave_pooling.cc -o src/layer/ave_pooling.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv.cc -o src/layer/conv.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv_cpu.cc -o src/layer/conv_cpu.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv_cust.cc -o src/layer/conv_cust.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/fully_connected.cc -o src/layer/fully_connected.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/max_pooling.cc -o src/layer/max_pooling.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/relu.cc -o src/layer/relu.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/sigmoid.cc -o src/layer/sigmoid.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/softmax.cc -o src/layer/softmax.o -I ../libgputk/ -I./

# !nvcc --compile src/layer/custom/cpu-new-forward.cc -o src/layer/custom/cpu-new-forward.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/custom/gpu-utils.cu -o src/layer/custom/gpu-utils.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/custom/gpu-new-forward-constant.cu -o src/layer/custom/gpu-new-forward-constant.o -I ../libgputk/ -I./

# !nvcc --compile src/loss/cross_entropy_loss.cc -o src/loss/cross_entropy_loss.o -I ../libgputk/ -I./
# !nvcc --compile src/loss/mse_loss.cc -o src/loss/mse_loss.o -I ../libgputk/ -I./

# !nvcc --compile demo.cc -I ../libgputk/ -I./
# !nvcc -o demo -lm -lcuda -lrt demo.o setup.o src/network.o src/mnist.o src/layer/*.o src/loss/*.o src/layer/custom/*.o -I ../libgputk/ -I./

# %%
! /content/Cuda_Lenet_5_Final/demo 128
# Out:
# Test batch size: 128
# Loading fashion-mnist data...60000,28,28
# 10000,28,28
# Done
# Loading model...Done
# Conv-GPU==
# Constant-memory
# Layer Time: 161.17 ms
# Op Time: 8.76742 ms
# Conv-GPU==
# Constant-memory
# Layer Time: 64.1836 ms
# Op Time: 18.1031 ms
#
# Test Accuracy: 0.9787

# %%
# !nvcc --compile setup.cc -I ../libgputk/ -I./

# !nvcc --compile src/network.cc -o src/network.o -I ../libgputk/ -I./

# !nvcc --compile src/mnist.cc -o src/mnist.o -I ../libgputk/ -I./

# !nvcc --compile src/layer/ave_pooling.cc -o src/layer/ave_pooling.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv.cc -o src/layer/conv.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv_cpu.cc -o src/layer/conv_cpu.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv_cust.cc -o src/layer/conv_cust.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/fully_connected.cc -o src/layer/fully_connected.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/max_pooling.cc -o src/layer/max_pooling.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/relu.cc -o src/layer/relu.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/sigmoid.cc -o src/layer/sigmoid.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/softmax.cc -o src/layer/softmax.o -I ../libgputk/ -I./

# !nvcc --compile src/layer/custom/cpu-new-forward.cc -o src/layer/custom/cpu-new-forward.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/custom/gpu-utils.cu -o src/layer/custom/gpu-utils.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/custom/gpu-new-forward-constant-smem.cu -o src/layer/custom/gpu-new-forward-constant-smem.o -I ../libgputk/ -I./

# !nvcc --compile src/loss/cross_entropy_loss.cc -o src/loss/cross_entropy_loss.o -I ../libgputk/ -I./
# !nvcc --compile src/loss/mse_loss.cc -o src/loss/mse_loss.o -I ../libgputk/ -I./

# !nvcc --compile demo.cc -I ../libgputk/ -I./
# !nvcc -o demo -lm -lcuda -lrt demo.o setup.o src/network.o src/mnist.o src/layer/*.o src/loss/*.o src/layer/custom/*.o -I ../libgputk/ -I./

# %%
! /content/Cuda_Lenet_5_Final/demo 128
# Out:
# Test batch size: 128
# Loading fashion-mnist data...60000,28,28
# 10000,28,28
# Done
# Loading model...Done
# Start Forward
# Conv-GPU==
# Constant-shared-memory
# Layer Time: 174.635 ms
# Op Time: 9.87085 ms
# Conv-GPU==
# Constant-shared-memory
# Layer Time: 62.4531 ms
# Op Time: 23.038 ms
# Time taken: 17974 milliseconds
#
# Test Accuracy: 0.9787

# %%
# !nvcc --compile setup.cc -I ../libgputk/ -I./

# !nvcc --compile src/network.cc -o src/network.o -I ../libgputk/ -I./

# !nvcc --compile src/mnist.cc -o src/mnist.o -I ../libgputk/ -I./

# !nvcc --compile src/layer/ave_pooling.cc -o src/layer/ave_pooling.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv.cc -o src/layer/conv.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv_cpu.cc -o src/layer/conv_cpu.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv_cust.cc -o src/layer/conv_cust.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/fully_connected.cc -o src/layer/fully_connected.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/max_pooling.cc -o src/layer/max_pooling.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/relu.cc -o src/layer/relu.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/sigmoid.cc -o src/layer/sigmoid.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/softmax.cc -o src/layer/softmax.o -I ../libgputk/ -I./

# !nvcc --compile src/layer/custom/cpu-new-forward.cc -o src/layer/custom/cpu-new-forward.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/custom/gpu-utils.cu -o src/layer/custom/gpu-utils.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/custom/gpu-new-forward-constant-smem-difflayer.cu -o src/layer/custom/gpu-new-forward-constant-smem-difflayer.o -I ../libgputk/ -I./

# !nvcc --compile src/loss/cross_entropy_loss.cc -o src/loss/cross_entropy_loss.o -I ../libgputk/ -I./
# !nvcc --compile src/loss/mse_loss.cc -o src/loss/mse_loss.o -I ../libgputk/ -I./

# !nvcc --compile demo.cc -I ../libgputk/ -I./
# !nvcc -o demo -lm -lcuda -lrt demo.o setup.o src/network.o src/mnist.o src/layer/*.o src/loss/*.o src/layer/custom/*.o -I ../libgputk/ -I./

# %%
! /content/Cuda_Lenet_5_Final/demo 128
# Out:
# Test batch size: 128
# Loading fashion-mnist data...60000,28,28
# 10000,28,28
# Done
# Loading model...Done
# Conv-GPU==
# Constant-shared memory, split layer
# Layer Time: 199.234 ms
# Op Time: 9.17076 ms
# Conv-GPU==
# Constant-shared memory, split layer
# Layer Time: 57.9338 ms
# Op Time: 19.5329 ms
#
# Test Accuracy: 0.9787

# %%
# !nvcc --compile setup.cc -I ../libgputk/ -I./

# !nvcc --compile src/network.cc -o src/network.o -I ../libgputk/ -I./

# !nvcc --compile src/mnist.cc -o src/mnist.o -I ../libgputk/ -I./

# !nvcc --compile src/layer/ave_pooling.cc -o src/layer/ave_pooling.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv.cc -o src/layer/conv.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv_cpu.cc -o src/layer/conv_cpu.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/conv_cust.cc -o src/layer/conv_cust.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/fully_connected.cc -o src/layer/fully_connected.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/max_pooling.cc -o src/layer/max_pooling.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/relu.cc -o src/layer/relu.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/sigmoid.cc -o src/layer/sigmoid.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/softmax.cc -o src/layer/softmax.o -I ../libgputk/ -I./

# !nvcc --compile src/layer/custom/cpu-new-forward.cc -o src/layer/custom/cpu-new-forward.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/custom/gpu-utils.cu -o src/layer/custom/gpu-utils.o -I ../libgputk/ -I./
# !nvcc --compile src/layer/custom/gpu-new-forward-constant-stream.cu -o src/layer/custom/gpu-new-forward-constant-stream.o -I ../libgputk/ -I./

# !nvcc --compile src/loss/cross_entropy_loss.cc -o src/loss/cross_entropy_loss.o -I ../libgputk/ -I./
# !nvcc --compile src/loss/mse_loss.cc -o src/loss/mse_loss.o -I ../libgputk/ -I./

# !nvcc --compile demo.cc -I ../libgputk/ -I./
# !nvcc -o demo -lm -lcuda -lrt demo.o setup.o src/network.o src/mnist.o src/layer/*.o src/loss/*.o src/layer/custom/*.o -I ../libgputk/ -I./

# %%
! /content/Cuda_Lenet_5_Final/demo 128
# Out:
# Test batch size: 128
# Loading fashion-mnist data...60000,28,28
# 10000,28,28
# Done
# Loading model...Done
# Conv-GPU==
# Constant-stream
# Layer Time: 156.525 ms
# Op Time: 5.09658 ms
# Conv-GPU==
# Constant-stream
# Layer Time: 42.574 ms
# Op Time: 4.47831 ms
#
# Test Accuracy: 0.1284
